# %% [markdown]
# # Diamond Prices

# %% [markdown]
# #### 1. According to the linear model provided, if a diamond is 1 carat heavier than another with the same cut and clarity, how much more should we expect to pay? Why?

# %% [markdown]
# A diamond 1 carat heavier than another is $8,413 more. If the other significant criteria is the same, the increase of Carat (+8413) in the regression formula, increases accordingly.

# %% [markdown]
# ![Diamond_Picture_2.png](attachment:Diamond_Picture_2.png)

# %% [markdown]
# #### 2.	If you were interested in a 1.5 carat diamond with a Very Good cut (represented by a 3 in the model) and a VS2 clarity rating (represented by a 5 in the model), how much would the model predict you should pay for it?

# %% [markdown]
# ![Diamond_Picture_1.png](attachment:Diamond_Picture_1.png)

# %% [markdown]
# Price = - 5,269 + 8,413 x Carat + 158.1 x Cut + 454 x Clarity <br>
#          = - 5269 + 8413 x (1.5) + 158.1 x (3) + 454 x (5) <br>
#          = $10094.8

# %% [markdown]
# Using linear regression model, it would cost **$10,094.80**

# %% [markdown]
# # Visualize the Data

# %% [markdown]
# #### 1. Plot the data for the diamonds in the database, with carat on the x-axis and price on the y-axis

# %% [markdown]
# ![Diamond_Picture_3.png](attachment:Diamond_Picture_3.png)

# %% [markdown]
# #### 2. Plot the data for the diamonds for which you are predicting prices with carat on the x-axis and predicted price on the y-axis.

# %% [markdown]
# ![Diamond_Picture_4.png](attachment:Diamond_Picture_4.png)

# %% [markdown]
# # 3. Make a Recommendation

# %% [markdown]
# #### What price do you recommend the jewelery company to bid? Please explain how you arrived at that number.

# %% [markdown]
# Used Alteryx to calculate the Linear Regression and applied that to the new-diamonds.csv data.
# 70% of the sum of the predicted prices are the recommended bidding price.
#
# - Predicting each diamond price with linear regression model
# - Summing up the predicted prices
# - Apply 70% on the summation for all predicted prices for bidding price
#
# Recommended bid price: **$8,211,163.15**
